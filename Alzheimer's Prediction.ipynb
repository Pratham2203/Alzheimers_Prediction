# %% [markdown]
# <img src="assets/images/banner.jpg" alt="banner" style="background-color: #ecf0f1; border-radius: 5px; text-align:center; color:#080205; font-weight:800; text-shadow: 2px 2px 2px #888888;">

# %% [markdown]
# <div style="padding: 10px; border-radius: 5px; color:#080205; font-family: 'Times New Roman', Times, serif;">
#     <h1 style="font-weight:800; font-size:30px;">Introduction</h1>
#     Alzheimer's disease is a complex neurodegenerative disorder that affects millions of people worldwide. Early detection and prediction of Alzheimer's can lead to better management and treatment outcomes. This prediction system utilizes a machine learning model trained on a dataset of relevant features to provide predictions about the likelihood of Alzheimer's disease.
#     <h1 style="font-weight:800; font-size:30px;">About Alzheimer's Disease</h1>
#     Alzheimer's disease (AD) is a progressive neurodegenerative disease. Though best known for its role in declining memory function, symptoms also include: difficulty thinking and reasoning, making judgements and decisions, and planning and performing familiar tasks. It may also cause alterations in personality and behavior. The cause of AD is not well understood. There is thought to be a significant hereditary component. For example, a variation of the APOE gene, APOE e4, increases risk of Alzheimer's disease.
#     <h1 style="font-weight:800; font-size:30px;">Purpose of the project</h1>
#     The purpose of this project proposal is to develop a machine learning model for the early prediction of Alzheimer's disease. Alzheimer's disease is a devastating neurodegenerative disorder that affects millions of individuals worldwide. Early detection is crucial for better patient care and the development of potential interventions. This project aims to leverage machine learning techniques to create a predictive model that can identify individuals at risk of Alzheimer's disease based on relevant data.
#     <h1 style="font-weight:800; font-size:30px;">Potential Impact</h1>
#     The potential impact of this project on the issue of Alzheimer's disease is significant:
#     - Early prediction of Alzheimer's disease can lead to timely interventions, potentially slowing down the progression of the disease.
#     - Accurate prediction models can aid in identifying suitable candidates for clinical trials and research studies.
#     - Providing a tool for early prediction can raise awareness about Alzheimer's disease and encourage individuals to seek early medical evaluation.
#     <br><br>
#     The model will be trained on a dataset collected from <a href="https://adni.loni.usc.edu/">Alzheimer’s Disease Neuroimaging Initiative (ADNI)</a>. This dataset is a comprehensive collection of clinical, imaging, and genetic data from individuals with Alzheimer's disease.
# </div>
#
# <h2 style="color: #000; font-family: 'Times New Roman', Times, serif;"><b>Variable Descriptions</b></h2>
# <table style="color: #000; width: 100%; border-collapse: collapse; margin-bottom: 20px;">
#     <tr>
#         <th style="color: #fff; background-color: #080205; border: 1px solid #fff; padding: 8px; text-align: left;">Variable</th>
#         <th style="color: #fff; background-color: #080205; border: 1px solid #fff; padding: 8px; text-align: left;">Description</th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">index</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">A numerical index for each row in the dataframe.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">directory.id</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">A unique identifier for each row in the dataframe.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">Subject</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">A unique identifier for each subject in the dataframe.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">RID</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">A numerical identifier for each subject in the dataframe.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">image.data.id</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">A numerical identifier for each image in the dataframe.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">Modality</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The type of imaging used to collect the data (MRI).</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">Visit</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The visit number associated with the data.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">Acq.Date</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The date on which the data was acquired.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">DX.bl</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The diagnosis at baseline (AD, LMCI, or CN).</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">EXAMDATE</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The date of the exam associated with the data.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">AGE</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The age of the subject at the time of the exam.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">PTGENDER</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The gender of the subject.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">PTEDUCAT</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The educational level of the subject.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">PTETHCAT</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The ethnicity of the subject (Hisp/Latino or Not Hisp/Latino).</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">PTRACCAT</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The race of the subject (White).</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">APOE4</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The APOE4 genotype of the subject (0, 1, or 2).</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">MMSE</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The Mini-Mental State Examination score of the subject.</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">imputed_genotype</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">Whether or not the genotype was imputed (True or False).</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">APOE Genotype</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The APOE genotype of the subject (3,3; 3,4; 4,3; 4,4).</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">Dx Codes for Submission</td>
#         <td style="border: 1px solid #fff; padding: 8px; text-align: left;">The diagnosis code for submission (AD, MCI, or CN).</td>
#     </tr>
# </table>

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Importing the libraries
# </h1>

# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
data = pd.read_csv('data/ADNI_Training_Q3_APOE_CollectionADNI1Complete 1Yr 1.5T_July22.2014.csv')

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Preprocessing
# </h1>

# %% [markdown]
# <div style="text-align:center; color:black; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Checking for NULL values
# </div>

# %%
data.isnull().sum()
# Out:
# directory.id               0
# Subject                    0
# RID                        0
# Image.Data.ID              0
# Modality                   0
# Visit                      0
# Acq.Date                   0
# DX.bl                      0
# EXAMDATE                   0
# AGE                        0
# PTGENDER                   0
# PTEDUCAT                   0
# PTETHCAT                   0
# PTRACCAT                   0
# APOE4                      0
# MMSE                       0
# imputed_genotype           1
# APOE Genotype              0
# Dx Codes for Submission    0
# dtype: int64

# %% [markdown]
# <div style="text-align:center; color:black; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Deleting NULL values
# </div>

# %%
data = data.dropna()
data.isnull().sum().sum()
# Out:
# 0

# %%
data.head(3)
# Out:
#                        directory.id     Subject  RID  Image.Data.ID Modality  \
# 0  4702245ea294ce5d4e9b8a87027dfdf4  011_S_0003    3          32237      MRI
# 1  2e89e352af743597b2368c412e0f6de2  022_S_0004    4          64631      MRI
# 2  90419199306997753de8042f1fd55e38  011_S_0005    5          32246      MRI
#
#    Visit    Acq.Date DX.bl    EXAMDATE   AGE PTGENDER  PTEDUCAT  \
# 0      1  09-01-2005    AD  09-12-2005  81.3     Male        18
# 1      1     9/22/05  LMCI  11-08-2005  67.5     Male        10
# 2      1  09-02-2005    CN  09-07-2005  73.7     Male        16
#
#           PTETHCAT PTRACCAT  APOE4  MMSE imputed_genotype APOE Genotype  \
# 0  Not Hisp/Latino    White      1    20             True           3,4
# 1      Hisp/Latino    White      0    27            False           3,3
# 2  Not Hisp/Latino    White      0    29             True           3,3
#
#   Dx Codes for Submission
# 0                      AD
# 1                     MCI
# 2                      CN

# %% [markdown]
# <div style="text-align:center; color:black; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Declaring Features (X) and Target (y) columns
# </div>

# %%
X = data
Y = data['DX.bl']
# del data

remove_columns = list(X.columns)[0:9]
remove_columns.append('Dx Codes for Submission')
print('Removing columns:', remove_columns)

X = X.drop(remove_columns, axis=1)

features = list(X.columns)
X.head(5)
# Out:
# Removing columns: ['directory.id', 'Subject', 'RID', 'Image.Data.ID', 'Modality', 'Visit', 'Acq.Date', 'DX.bl', 'EXAMDATE', 'Dx Codes for Submission']
#     AGE PTGENDER  PTEDUCAT         PTETHCAT PTRACCAT  APOE4  MMSE  \
# 0  81.3     Male        18  Not Hisp/Latino    White      1    20
# 1  67.5     Male        10      Hisp/Latino    White      0    27
# 2  73.7     Male        16  Not Hisp/Latino    White      0    29
# 3  80.4   Female        13  Not Hisp/Latino    White      0    25
# 4  73.9   Female        12  Not Hisp/Latino    White      1    24
#
#   imputed_genotype APOE Genotype
# 0             True           3,4
# 1            False           3,3
# 2             True           3,3
# 3             True           3,3
# 4             True           3,4

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Exploratory Data Analysis (EDA)
# </h1>

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.5em;">
#     Relationship between age and diagnosis (DX.bl) by plotting a scatterplot of age against diagnosis.
# </div>

# %%
plt.scatter(data['AGE'], data['DX.bl'])

plt.xlabel('Age')
plt.ylabel('Diagnosis')

plt.show()

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Counts of gender and ethnicity across different diagnoses
# </div>

# %%
gender_ethnicity_counts = data.groupby(['DX.bl', 'PTGENDER', 'PTETHCAT']).size().reset_index(name='count')
print(gender_ethnicity_counts)
# Out:
#    DX.bl PTGENDER         PTETHCAT  count
# 0     AD   Female  Not Hisp/Latino     64
# 1     AD   Female          Unknown      1
# 2     AD     Male  Not Hisp/Latino     68
# 3     CN   Female      Hisp/Latino      2
# 4     CN   Female  Not Hisp/Latino     89
# 5     CN   Female          Unknown      1
# 6     CN     Male  Not Hisp/Latino     98
# 7   LMCI   Female      Hisp/Latino      4
# 8   LMCI   Female  Not Hisp/Latino    102
# 9   LMCI   Female          Unknown      1
# 10  LMCI     Male      Hisp/Latino      2
# 11  LMCI     Male  Not Hisp/Latino    195

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Relationship between APOE4 genotype and diagnosis (DX.bl)
# </div>

# %%
sns.countplot(x='APOE4', hue='DX.bl', data=data)
plt.title('Relationship between APOE4 genotype and diagnosis')
plt.xlabel('APOE4 Genotype')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Scatterplot of MMSE score against diagnosis
# </div>

# %%
plt.scatter(data['MMSE'], data['DX.bl'])

plt.xlabel('MMSE Score')
plt.ylabel('Diagnosis')

plt.show()

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Plotting the counts of imputed genotype (imputed_genotype) across different diagnoses (DX.bl)
# </div>

# %%
counts = data.groupby(['DX.bl', 'imputed_genotype']).size().reset_index(name='counts')

plt.figure(figsize=(10,6))
ax = sns.barplot(x="DX.bl", y="counts", hue="imputed_genotype", data=counts)
ax.set_title('Distribution of Imputed Genotype Across Different Diagnoses')
plt.show()

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.5em;">
#     Relationship between APOE Genotype and diagnosis (DX.bl) by plotting a bar chart of APOE Genotype against diagnosis.
# </div>

# %%
ax = data.groupby(['APOE Genotype', 'DX.bl']).size().unstack().plot(kind='bar', figsize=(10,6))

ax.set_title('APOE Genotype vs Diagnosis')
ax.set_xlabel('APOE Genotype')
ax.set_ylabel('Diagnosis')

plt.show()

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Categorical Variable Distributions
# </div>

# %%
numerical_vars = ['AGE', 'MMSE', 'PTEDUCAT']
cat_vars = list(set(features) - set(numerical_vars))

print('Categorical variable distributions:\n')

for var in cat_vars:
    print('\nDistribution of', var)
    
    print(X[var].value_counts())
# Out:
# Categorical variable distributions:
#
#
# Distribution of PTRACCAT
# PTRACCAT
# White    583
# Black     31
# Asian     13
# Name: count, dtype: int64
#
# Distribution of APOE4
# APOE4
# 0    322
# 1    234
# 2     71
# Name: count, dtype: int64
#
# Distribution of APOE Genotype
# APOE Genotype
# 3,3    275
# 3,4    221
# 4,4     71
# 2,3     45
# 2,4     13
# 2,2      2
# Name: count, dtype: int64
#
# Distribution of PTGENDER
# PTGENDER
# Male      363
# Female    264
# Name: count, dtype: int64
#
# Distribution of imputed_genotype
# imputed_genotype
# True     466
# False    161
# Name: count, dtype: int64
#
# Distribution of PTETHCAT
# PTETHCAT
# Not Hisp/Latino    616
# Hisp/Latino          8
# Unknown              3
# Name: count, dtype: int64

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Numerical Variable Distributions
# </div>

# %%
print('Numerical Var Distributions:\n')

for var in numerical_vars:
    plt.hist(X[var], bins=10)
    plt.title(var + ' Distribution')
    plt.show()
    
    print(X[var].describe())
# Out:
# Numerical Var Distributions:
# count    627.000000
# mean      75.161882
# std        6.689979
# min       55.100000
# 25%       71.200000
# 50%       75.400000
# 75%       80.000000
# max       89.600000
# Name: AGE, dtype: float64
# count    627.000000
# mean      26.921850
# std        2.563934
# min       20.000000
# 25%       25.000000
# 50%       27.000000
# 75%       29.000000
# max       30.000000
# Name: MMSE, dtype: float64
# count    627.000000
# mean      15.612440
# std        2.978845
# min        6.000000
# 25%       13.000000
# 50%       16.000000
# 75%       18.000000
# max       20.000000
# Name: PTEDUCAT, dtype: float64

# %% [markdown]
# <!-- <p style="color: #3498db; font-size: 18px; font-weight: bold;">Stylish Text 1</p>
# <p style="font-family: 'Courier New', monospace; font-size: 20px; color: #2ecc71;">Stylish Text 2</p>
# <p style="text-transform: uppercase; letter-spacing: 2px; font-size: 16px; color: #e74c3c;">Stylish Text 3</p>
# <p style="font-style: italic; font-size: 22px; color: #f39c12;">Stylish Text 4</p>
# <p style="text-decoration: underline; font-size: 18px; color: #9b59b6;">Stylish Text 5</p>
# <p style="font-family: 'Times New Roman', serif; font-size: 24px; color: #34495e;">Stylish Text 6</p>
# <p style="font-weight: 700; font-size: 20px; color: #1abc9c;">Stylish Text 8</p>
# <p style="text-shadow: 2px 2px 4px #888888; font-size: 18px; color: #c0392b;">Stylish Text 9</p>
# <p style="font-size: 22px; color: #3498db; transform: rotate(15deg);">Stylish Text 10</p> -->

# %% [markdown]
# <div style="text-align:center; color:orange; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 1.7em;">
#     Analyzing target (y) distribution
# </div>

# %%
plt.bar(Y.value_counts().index, Y.value_counts())
plt.show()

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Preprocessing
# </h1>

# %% [markdown]
# <div style="text-align:center; color:yellow; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2em;">
#     Converting the Categorical Variables to 1-Hot
# </div>

# %%
for var in cat_vars:
    print(f'Converting {var} to 1-hot encoding')
    one_hot_df = pd.get_dummies(X[var], prefix=var)
    X = pd.concat([X, one_hot_df], axis=1)
    X.drop(var, axis=1, inplace=True)
    
X.head(4)
# Out:
# Converting PTRACCAT to 1-hot encoding
# Converting APOE4 to 1-hot encoding
# Converting APOE Genotype to 1-hot encoding
# Converting PTGENDER to 1-hot encoding
# Converting imputed_genotype to 1-hot encoding
# Converting PTETHCAT to 1-hot encoding
#     AGE  PTEDUCAT  MMSE  PTRACCAT_Asian  PTRACCAT_Black  PTRACCAT_White  \
# 0  81.3        18    20           False           False            True
# 1  67.5        10    27           False           False            True
# 2  73.7        16    29           False           False            True
# 3  80.4        13    25           False           False            True
#
#    APOE4_0  APOE4_1  APOE4_2  APOE Genotype_2,2  ...  APOE Genotype_3,3  \
# 0    False     True    False              False  ...              False
# 1     True    False    False              False  ...               True
# 2     True    False    False              False  ...               True
# 3     True    False    False              False  ...               True
#
#    APOE Genotype_3,4  APOE Genotype_4,4  PTGENDER_Female  PTGENDER_Male  \
# 0               True              False            False           True
# 1              False              False            False           True
# 2              False              False            False           True
# 3              False              False             True          False
#
#    imputed_genotype_False  imputed_genotype_True  PTETHCAT_Hisp/Latino  \
# 0                   False                   True                 False
# 1                    True                  False                  True
# 2                   False                   True                 False
# 3                   False                   True                 False
#
#    PTETHCAT_Not Hisp/Latino  PTETHCAT_Unknown
# 0                      True             False
# 1                     False             False
# 2                      True             False
# 3                      True             False
#
# [4 rows x 22 columns]

# %% [markdown]
# <div style="text-align:center; color:yellow; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2em;">
#     Normalization function
# </div>

# %%
def normalize(X):
    X = np.array(X)
    means = np.mean(X, axis=0)
    stds = np.std(X, axis=0)

    normalized_X = (X - means) / stds

    print('Normalizing:')
    for i, (mean, std) in enumerate(zip(means, stds)):
        print(f'  Variable {i+1}: Mean = {mean:.2f}, Standard Deviation = {std:.2f}')

    return normalized_X

# %% [markdown]
# <div style="text-align:center; color:yellow; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2em;">
#     Splitting the dataset
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2)

num_test = X_test.shape[0]

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Comparing between models
# </h1>

# %%
X_train.columns = X_train.columns.astype(str)
X_test.columns = X_test.columns.astype(str)

# %% [markdown]
# ### Checking each model's accuracy

# %% [markdown]
# <div style="text-align:center; color:lightgreen; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2.0em;">
#     Linear Discriminant Analysis
# </div>

# %%
lda_clf = LinearDiscriminantAnalysis(solver='svd', store_covariance=False, tol=0.0001)
lda_clf.fit(X_train, y_train)

y_pred = lda_clf.predict(X_test)

print('Cross Validation:', format(cross_val_score(lda_clf, X_train, y_train, cv=5).mean(), '.2%'))
print('Accuracy:', format(accuracy_score(y_test, y_pred), '.2%'))
print('Precision:', format(precision_score(y_test, y_pred, average='weighted'), '.2%'))
print('Recall:', format(recall_score(y_test, y_pred, average='weighted'), '.2%'))
print('F1 Score:', format(f1_score(y_test, y_pred, average='weighted'), '.2%'))

print('Confusion Matrix:')
conf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(conf_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Cross Validation: 68.86%
# Accuracy: 65.87%
# Precision: 66.38%
# Recall: 65.87%
# F1 Score: 66.02%
# Confusion Matrix:

# %% [markdown]
# <div style="text-align:center; color:lightgreen; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2.0em;">
#     Logistic Regression
# </div>

# %%
log_clf = LogisticRegression(solver='lbfgs', penalty='l2', max_iter=1000000, multi_class='multinomial')
log_clf.fit(X_train, y_train)

y_pred = log_clf.predict(X_test)

print('Cross Validation:', format(cross_val_score(log_clf, X_train, y_train, cv=5).mean(), '.2%'))
print('Accuracy:', format(accuracy_score(y_test, y_pred), '.2%'))
print('Precision:', format(precision_score(y_test, y_pred, average='weighted'), '.2%'))
print('Recall:', format(recall_score(y_test, y_pred, average='weighted'), '.2%'))
print('F1 Score:', format(f1_score(y_test, y_pred, average='weighted'), '.2%'))

print('Confusion Matrix:')
conf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(conf_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Cross Validation: 71.46%
# Accuracy: 63.49%
# Precision: 64.03%
# Recall: 63.49%
# F1 Score: 63.58%
# Confusion Matrix:

# %% [markdown]
# <div style="text-align:center; color:lightgreen; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2.0em;">
#     Random Forest Classifier
# </div>

# %%
rf_clf = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                                criterion='gini', max_depth=None, max_features='sqrt',
                                max_leaf_nodes=None, max_samples=None,
                                min_impurity_decrease=0.0, min_samples_leaf=1,
                                min_samples_split=2, min_weight_fraction_leaf=0.0,
                                n_estimators=100, n_jobs=-1, oob_score=False,
                                random_state=123, verbose=0, warm_start=False)

rf_clf.fit(X_train, y_train)

y_pred = rf_clf.predict(X_test)

print('Cross Validation:', format(cross_val_score(rf_clf, X_train, y_train, cv=5).mean(), '.2%'))
print('Accuracy:', format(accuracy_score(y_test, y_pred), '.2%'))
print('Precision:', format(precision_score(y_test, y_pred, average='weighted'), '.2%'))
print('Recall:', format(recall_score(y_test, y_pred, average='weighted'), '.2%'))
print('F1 Score:', format(f1_score(y_test, y_pred, average='weighted'), '.2%'))

print('Confusion Matrix:')
conf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(conf_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Cross Validation: 64.46%
# Accuracy: 57.14%
# Precision: 57.65%
# Recall: 57.14%
# F1 Score: 57.07%
# Confusion Matrix:

# %% [markdown]
# <div style="text-align:center; color:lightgreen; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2.0em;">
#     Ridge Classifier
# </div>

# %%
rg_clf = RidgeClassifier(alpha=1.0, copy_X=True, fit_intercept=True, random_state=123, solver='auto', tol=0.0001)
rg_clf.fit(X_train, y_train)

y_pred = rg_clf.predict(X_test)

print('Cross Validation:', format(cross_val_score(rg_clf, X_train, y_train, cv=5).mean(), '.2%'))
print('Accuracy:', format(accuracy_score(y_test, y_pred), '.2%'))
print('Precision:', format(precision_score(y_test, y_pred, average='weighted'), '.2%'))
print('Recall:', format(recall_score(y_test, y_pred, average='weighted'), '.2%'))
print('F1 Score:', format(f1_score(y_test, y_pred, average='weighted'), '.2%'))

print('Confusion Matrix:')
conf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(conf_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Cross Validation: 63.87%
# Accuracy: 57.14%
# Precision: 57.60%
# Recall: 57.14%
# F1 Score: 57.18%
# Confusion Matrix:

# %% [markdown]
# <div style="text-align:center; color:lightgreen; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2.0em;">
#     Gradient Boosting Classifier
# </div>

# %%
gb_clf = GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
                            learning_rate=0.1, loss='log_loss', max_depth=3,
                            max_features=None, max_leaf_nodes=None,
                            min_impurity_decrease=0.0, min_samples_leaf=1,
                            min_samples_split=2, min_weight_fraction_leaf=0.0,
                            n_estimators=100, n_iter_no_change=None,
                            random_state=123, subsample=1.0, tol=0.0001,
                            validation_fraction=0.1, verbose=0,
                            warm_start=False)

gb_clf.fit(X_train, y_train)

y_pred = gb_clf.predict(X_test)

print('Cross Validation:', format(cross_val_score(gb_clf, X_train, y_train, cv=5).mean(), '.2%'))
print('Accuracy:', format(accuracy_score(y_test, y_pred), '.2%'))
print('Precision:', format(precision_score(y_test, y_pred, average='weighted'), '.2%'))
print('Recall:', format(recall_score(y_test, y_pred, average='weighted'), '.2%'))
print('F1 Score:', format(f1_score(y_test, y_pred, average='weighted'), '.2%'))

print('Confusion Matrix:')
conf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(conf_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Cross Validation: 67.66%
# Accuracy: 63.49%
# Precision: 63.61%
# Recall: 63.49%
# F1 Score: 63.45%
# Confusion Matrix:

# %% [markdown]
# <div style="text-align:center; color:lightgreen; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2.0em;">
#     Multi-layer Perceptron (MLP) Classifier
# </div>

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(15, 10), alpha=3, learning_rate='adaptive', max_iter=100000)
mlp_clf.fit(X_train, y_train)

y_pred = mlp_clf.predict(X_test)

print('Cross Validation:', format(cross_val_score(mlp_clf, X_train, y_train, cv=5).mean(), '.2%'))
print('Accuracy:', format(accuracy_score(y_test, y_pred), '.2%'))
print('Precision:', format(precision_score(y_test, y_pred, average='weighted'), '.2%'))
print('Recall:', format(recall_score(y_test, y_pred, average='weighted'), '.2%'))
print('F1 Score:', format(f1_score(y_test, y_pred, average='weighted'), '.2%'))

print('Confusion Matrix:')
conf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(conf_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Cross Validation: 51.47%
# Accuracy: 61.90%
# Precision: 61.76%
# Recall: 61.90%
# F1 Score: 61.39%
# Confusion Matrix:

# %% [markdown]
# <div style="text-align:center; color:lightgreen; font-weight:600; font-family: 'Courier New', Times, serif; font-size: 2.0em;">
#     Conclusion
# </div>

# %% [markdown]
# <!-- <center>
#   <table>
#     <thead>
#       <tr>
#         <th>Model</th>
#         <th>Cross Val</th>
#         <th>Accuracy</th>
#         <th>Precision</th>
#         <th>Recall</th>
#         <th>F1 Score</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>Linear Discriminant Analysis</td>
#         <td>69.86</td>
#         <td>66.67</td>
#         <td>67.52</td>
#         <td>66.67</td>
#         <td>66.62</td>
#       </tr>
#       <tr style="background-color: green;">
#         <td>Logistic Regression</td>
#         <td>70.66</td>
#         <td>68.25</td>
#         <td>68.63</td>
#         <td>68.25</td>
#         <td>68.12</td>
#       </tr>
#       <tr>
#         <td>Random Forest Classifier</td>
#         <td>65.66</td>
#         <td>64.29</td>
#         <td>63.94</td>
#         <td>64.29</td>
#         <td>63.87</td>
#       </tr>
#       <tr>
#         <td>Ridge Classifier</td>
#         <td>64.87</td>
#         <td>63.49</td>
#         <td>65.01</td>
#         <td>63.49</td>
#         <td>63.51</td>
#       </tr>
#       <tr>
#         <td>Gradient Boosting Classifier</td>
#         <td>66.27</td>
#         <td>64.29</td>
#         <td>65.17</td>
#         <td>64.29</td>
#         <td>64.07</td>
#       </tr>
#       <tr>
#         <td>MLP Classifier</td>
#         <td>51.28</td>
#         <td>63.29</td>
#         <td>63.61</td>
#         <td>63.49</td>
#         <td>62.97</td>
#       </tr>
#     </tbody>
#   </table>
# </center> -->
#
# Choosing Logistic Regression with validation Score .67

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Model Selection
# </h1>

# %% [markdown]
# ### Testing Logistic Regression Model

# %%
log_clf_preds = log_clf.predict(X_test)
    
log_clf_accuracy = (log_clf_preds == y_test)
print('Test Accuracy =', format( np.sum(log_clf_accuracy)/num_test, '.2%'))
# Out:
# Test Accuracy = 74.60%

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Performance Analysis
# </h1>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

log_clf = LogisticRegression(solver='lbfgs', penalty='l2', max_iter=1000000, multi_class='multinomial')
log_clf.fit(X_train, y_train)
log_clf_preds = log_clf.predict(X_test)

print('Logistic Regression:')
print('Accuracy:', format(accuracy_score(y_test, log_clf_preds), '.2%'))
print('Precision:', format(precision_score(y_test, log_clf_preds, average='weighted'), '.2%'))
print('Recall:', format(recall_score(y_test, log_clf_preds, average='weighted'), '.2%'))
print('F1 Score:', format(f1_score(y_test, log_clf_preds, average='weighted'), '.2%'))
# Out:
# Logistic Regression:
# Accuracy: 63.49%
# Precision: 64.03%
# Recall: 63.49%
# F1 Score: 63.58%

# %% [markdown]
# <h1 style="background-color: #080205; padding: 10px; border-radius: 5px; text-align:center; color:#ecf0f1; font-weight:600; text-shadow: 2px 2px 2px #888888;">
#     Exporting the final model
# </h1>

# %%
# joblib.dump(log_clf, 'model/alzheimer_model.pkl')

# %%
X_train
# Out:
#       AGE  PTEDUCAT  MMSE  APOE Genotype_2,2  APOE Genotype_2,3  \
# 407  88.6        20    30              False              False
# 85   80.4        13    29              False               True
# 385  87.1        16    24              False              False
# 565  73.4        20    27              False               True
# 593  76.5        11    26              False              False
# ..    ...       ...   ...                ...                ...
# 167  56.5        20    23              False              False
# 513  69.7        14    25              False              False
# 241  62.8        18    28              False              False
# 430  84.8        18    28              False              False
# 92   78.3        17    30              False              False
#
#      APOE Genotype_2,4  APOE Genotype_3,3  APOE Genotype_3,4  \
# 407              False               True              False
# 85               False              False              False
# 385              False              False              False
# 565              False              False              False
# 593              False               True              False
# ..                 ...                ...                ...
# 167              False               True              False
# 513              False              False              False
# 241              False              False               True
# 430              False               True              False
# 92               False               True              False
#
#      APOE Genotype_4,4  PTETHCAT_Hisp/Latino  ...  PTRACCAT_Asian  \
# 407              False                 False  ...           False
# 85               False                 False  ...           False
# 385               True                 False  ...           False
# 565              False                 False  ...           False
# 593              False                 False  ...           False
# ..                 ...                   ...  ...             ...
# 167              False                 False  ...           False
# 513               True                 False  ...           False
# 241              False                 False  ...           False
# 430              False                 False  ...           False
# 92               False                 False  ...           False
#
#      PTRACCAT_Black  PTRACCAT_White  imputed_genotype_False  \
# 407           False            True                    True
# 85            False            True                   False
# 385           False            True                   False
# 565           False            True                   False
# 593           False            True                    True
# ..              ...             ...                     ...
# 167           False            True                   False
# 513           False            True                   False
# 241           False            True                    True
# 430           False            True                   False
# 92            False            True                    True
#
#      imputed_genotype_True  PTGENDER_Female  PTGENDER_Male  APOE4_0  APOE4_1  \
# 407                  False             True          False     True    False
# 85                    True             True          False     True    False
# 385                   True            False           True    False    False
# 565                   True            False           True     True    False
# 593                  False             True          False     True    False
# ..                     ...              ...            ...      ...      ...
# 167                   True             True          False     True    False
# 513                   True             True          False    False    False
# 241                  False            False           True    False     True
# 430                   True            False           True     True    False
# 92                   False             True          False     True    False
#
#      APOE4_2
# 407    False
# 85     False
# 385     True
# 565    False
# 593    False
# ..       ...
# 167    False
# 513     True
# 241    False
# 430    False
# 92     False
#
# [501 rows x 22 columns]

# %%
for col, dtype in X_train.dtypes.items():
    print(f"{col}: {dtype}")
# Out:
# AGE: float64
# PTEDUCAT: int64
# MMSE: int64
# APOE Genotype_2,2: bool
# APOE Genotype_2,3: bool
# APOE Genotype_2,4: bool
# APOE Genotype_3,3: bool
# APOE Genotype_3,4: bool
# APOE Genotype_4,4: bool
# PTETHCAT_Hisp/Latino: bool
# PTETHCAT_Not Hisp/Latino: bool
# PTETHCAT_Unknown: bool
# PTRACCAT_Asian: bool
# PTRACCAT_Black: bool
# PTRACCAT_White: bool
# imputed_genotype_False: bool
# imputed_genotype_True: bool
# PTGENDER_Female: bool
# PTGENDER_Male: bool
# APOE4_0: bool
# APOE4_1: bool
# APOE4_2: bool

# %%
y_train
# Out:
# 407      CN
# 85     LMCI
# 385    LMCI
# 565    LMCI
# 593    LMCI
#        ...
# 167      AD
# 513    LMCI
# 241      CN
# 430      CN
# 92       CN
# Name: DX.bl, Length: 501, dtype: object

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class TabularAttention(nn.Module):
    def __init__(self, input_dim):
        super(TabularAttention, self).__init__()
        self.attn = nn.Linear(input_dim, input_dim)
    
    def forward(self, x):
        # x shape: (batch_size, input_dim)
        attn_weights = torch.sigmoid(self.attn(x))  # (batch_size, input_dim)
        x_attended = x * attn_weights  # Element-wise multiplication
        return x_attended, attn_weights

class AttentionMLP(nn.Module):
    def __init__(self, input_dim, hidden_dims, output_dim):
        super(AttentionMLP, self).__init__()
        self.attention = TabularAttention(input_dim)
        self.mlp = nn.Sequential(
            nn.Linear(input_dim, hidden_dims[0]),
            nn.ReLU(),
            nn.Linear(hidden_dims[0], hidden_dims[1]),
            nn.ReLU(),
            nn.Linear(hidden_dims[1], output_dim)
        )
    
    def forward(self, x):
        x_attended, attn_weights = self.attention(x)
        out = self.mlp(x_attended)
        return out, attn_weights

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# LSTM Attention Model
class LSTMAttention(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTMAttention, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.attention = nn.Linear(hidden_dim, 1)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # x shape: (batch_size, seq_len, input_dim) - treat each row as a sequence
        lstm_out, _ = self.lstm(x)  # lstm_out: (batch_size, seq_len, hidden_dim)

        # Attention mechanism
        attn_weights = torch.softmax(self.attention(lstm_out).squeeze(2), dim=1)  # (batch_size, seq_len)
        context = torch.bmm(attn_weights.unsqueeze(1), lstm_out).squeeze(1)  # (batch_size, hidden_dim)

        out = self.fc(context)
        return out, attn_weights

def train_and_evaluate(X_train, y_train, X_test, y_test, num_epochs=100, lr=0.001, hidden_dim=32, num_layers=2):
    # Convert to torch tensors
    X_train_t = torch.tensor(X_train, dtype=torch.float32)
    y_train_t = torch.tensor(y_train, dtype=torch.long)
    X_test_t = torch.tensor(X_test, dtype=torch.float32)
    y_test_t = torch.tensor(y_test, dtype=torch.long)

    input_dim = X_train.shape[1]
    output_dim = len(np.unique(y_train))

    # Reshape input data for LSTM
    X_train_t = X_train_t.unsqueeze(1)  # (batch_size, seq_len=1, input_dim)
    X_test_t = X_test_t.unsqueeze(1)

    model = LSTMAttention(input_dim=input_dim, hidden_dim=hidden_dim, num_layers=num_layers, output_dim=output_dim)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        outputs, attn_weights = model(X_train_t)
        loss = criterion(outputs, y_train_t)
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        test_outputs, test_attn_weights = model(X_test_t)
        _, y_pred = torch.max(test_outputs, 1)

    y_pred_np = y_pred.numpy()
    y_test_np = y_test_t.numpy()

    acc = accuracy_score(y_test_np, y_pred_np)
    prec = precision_score(y_test_np, y_pred_np, average='weighted')
    rec = recall_score(y_test_np, y_pred_np, average='weighted')
    f1 = f1_score(y_test_np, y_pred_np, average='weighted')
    conf_mat = confusion_matrix(y_test_np, y_pred_np)

    print(f'Accuracy: {acc:.2%}')
    print(f'Precision: {prec:.2%}')
    print(f'Recall: {rec:.2%}')
    print(f'F1 Score: {f1:.2%}')

    sns.heatmap(conf_mat, annot=True, cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return model, test_attn_weights

# %%
X_train_np = X_train.astype(float).to_numpy()
X_test_np = X_test.astype(float).to_numpy()

if y_train.dtype == 'O' or str(y_train.dtype).startswith('category'):
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_np = le.fit_transform(y_train)
    y_test_np = le.transform(y_test)
else:
    y_train_np = y_train.to_numpy()
    y_test_np = y_test.to_numpy()

model, attn_weights = train_and_evaluate(X_train_np, y_train_np, X_test_np, y_test_np, num_epochs=100, lr=0.001, hidden_dim=32, num_layers=2)
# Out:
# Accuracy: 62.70%
# Precision: 63.68%
# Recall: 62.70%
# F1 Score: 62.26%

# %% [markdown]
# ### LSTM Layer
# This layer processes the input data, treating each row of the tabular data as a sequence. It captures temporal dependencies within the data, which helps to understand the relationships between different features.
#
# ### Attention Mechanism
# The attention mechanism assigns weights to each feature in the input data, highlighting the most important features for classification. This allows the model to focus on the most relevant information and ignore the less important details.
#
# ### Fully Connected Layer
# The fully connected layer takes the output from the LSTM layer and attention mechanism and produces a classification decision. This layer maps the learned features to the different classes.
#
# ### Classification
# Based on the weighted features, the model classifies each input into one of the three categories: AD (Alzheimer's Disease), LMCI (Late Mild Cognitive Impairment), or CN (Cognitively Normal).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Feature-wise Attention
class FeatureWiseAttention(nn.Module):
    def __init__(self, input_dim):
        super(FeatureWiseAttention, self).__init__()
        self.attention = nn.Linear(input_dim, 1)

    def forward(self, x):
        attn_weights = torch.sigmoid(self.attention(x))
        x_attended = x * attn_weights
        return x_attended

# 2. Gated Residual Network (GRN)
class GatedResidualNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout):
        super(GatedResidualNetwork, self).__init__()
        self.linear1 = nn.Linear(input_dim, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, output_dim)
        self.gate = nn.Linear(input_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        self.norm = nn.LayerNorm(output_dim)

    def forward(self, x):
        residual = x
        x = self.linear1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        gate = torch.sigmoid(self.gate(residual))
        x = gate * x + (1 - gate) * residual
        x = self.norm(x)
        return x

# 3. Hybrid Attention Model with GRN
class HybridAttentionGRN(nn.Module):
    def __init__(self, num_numerical_features, grn_hidden_dim, num_layers, output_dim, dropout):
        super(HybridAttentionGRN, self).__init__()
        self.feature_attention = FeatureWiseAttention(num_numerical_features)
        self.grn_layers = nn.ModuleList([
            GatedResidualNetwork(num_numerical_features, grn_hidden_dim, num_numerical_features, dropout)
            for _ in range(num_layers)
        ])
        self.linear = nn.Linear(num_numerical_features, output_dim)

    def forward(self, x_numerical):
        x = self.feature_attention(x_numerical)
        for layer in self.grn_layers:
            x = layer(x)
        out = self.linear(x)
        return out, None

def train_and_evaluate(X_train, y_train, X_test, y_test, num_epochs=100, lr=0.001, grn_hidden_dim=64, num_layers=4, dropout=0.1):
    # Convert to torch tensors
    X_train_t = torch.tensor(X_train, dtype=torch.float32)
    y_train_t = torch.tensor(y_train, dtype=torch.long)
    X_test_t = torch.tensor(X_test, dtype=torch.float32)
    y_test_t = torch.tensor(y_test, dtype=torch.long)

    num_numerical_features = X_train.shape[1]
    output_dim = len(np.unique(y_train))

    model = HybridAttentionGRN(
        num_numerical_features=num_numerical_features,
        grn_hidden_dim=grn_hidden_dim,
        num_layers=num_layers,
        output_dim=output_dim,
        dropout=dropout
    )

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        outputs, _ = model(X_train_t)
        loss = criterion(outputs, y_train_t)
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        test_outputs, _ = model(X_test_t)
        _, y_pred = torch.max(test_outputs, 1)

    y_pred_np = y_pred.numpy()
    y_test_np = y_test_t.numpy()

    acc = accuracy_score(y_test_np, y_pred_np)
    prec = precision_score(y_test_np, y_pred_np, average='weighted')
    rec = recall_score(y_test_np, y_pred_np, average='weighted')
    f1 = f1_score(y_test_np, y_pred_np, average='weighted')
    conf_mat = confusion_matrix(y_test_np, y_pred_np)

    print(f'Accuracy: {acc:.2%}')
    print(f'Precision: {prec:.2%}')
    print(f'Recall: {rec:.2%}')
    print(f'F1 Score: {f1:.2%}')

    sns.heatmap(conf_mat, annot=True, cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return model, None

# Example usage:
# Assuming X_train, y_train, X_test, y_test are prepared numpy arrays

# Ensure all columns in X_train and X_test are numeric
X_train_np = X_train.astype(float).to_numpy()
X_test_np = X_test.astype(float).to_numpy()

# Encode labels
if y_train.dtype == 'O' or str(y_train.dtype).startswith('category'):
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_np = le.fit_transform(y_train)
    y_test_np = le.transform(y_test)
else:
    y_train_np = y_train.to_numpy()
    y_test_np = y_test.to_numpy()

# Train and evaluate the model
model, _ = train_and_evaluate(
    X_train_np, y_train_np, X_test_np, y_test_np,
    num_epochs=100, lr=0.001, grn_hidden_dim=64, num_layers=4, dropout=0.1
)
# Out:
# C:\Users\pratham goel\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 49.21%
# Precision: 24.21%
# Recall: 49.21%
# F1 Score: 32.46%

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Attention, Embedding, Concatenate, LayerNormalization, Dropout, GlobalAveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns



def load_and_clean_data():
    # Load dataset
    df = pd.read_csv('data/ADNI_Training_Q3_APOE_CollectionADNI1Complete 1Yr 1.5T_July22.2014.csv')
    
    # Validate critical columns
    required_cols = ['RID', 'AGE', 'PTGENDER', 'PTEDUCAT', 'APOE4', 'imputed_genotype', 
                    'APOE Genotype', 'MMSE', 'DX.bl', 'EXAMDATE']
    missing_cols = [col for col in required_cols if col not in df.columns]
    if missing_cols:
        raise ValueError(f"Missing required columns: {missing_cols}")
    
    # Convert exam dates
    df['EXAMDATE'] = pd.to_datetime(df['EXAMDATE'], errors='coerce')
    
    # Handle missing values
    initial_count = len(df)
    df = df.dropna(subset=['DX.bl', 'MMSE', 'APOE4', 'APOE Genotype'])
    print(f"Retained {len(df)}/{initial_count} samples after initial cleaning")
    
    # Process APOE Genotype with error handling
    genotype_split = df['APOE Genotype'].str.split(',', expand=True)
    df[['Allele1', 'Allele2']] = genotype_split.apply(pd.to_numeric, errors='coerce')
    df = df.dropna(subset=['Allele1', 'Allele2'])
    
    # Handle imputed_genotype
    df['imputed_genotype'] = df['imputed_genotype'].fillna(0).astype(int)
    
    # Fill remaining missing values
    df['PTEDUCAT'] = df['PTEDUCAT'].fillna(df['PTEDUCAT'].median())
    
    # Encode variables
    df['PTGENDER'] = df['PTGENDER'].map({'Male': 0, 'Female': 1}).astype(int)
    
    # Label encoding
    le = LabelEncoder()
    df['DX.bl'] = le.fit_transform(df['DX.bl'])
    
    return df, le

cleaned_df, label_encoder = load_and_clean_data()

# Step 4: Temporal Data Preparation with Enhanced Padding
def create_sequences(df, max_visits=3, time_window=365):
    features = ['AGE', 'PTGENDER', 'PTEDUCAT', 'APOE4', 'imputed_genotype', 
               'Allele1', 'Allele2', 'MMSE']
    grouped = df.sort_values('EXAMDATE').groupby('RID')
    
    sequences = []
    labels = []
    
    for name, group in grouped:
        if len(group) < 1:
            continue
            
        group = group.sort_values('EXAMDATE')
        time_diff = (group['EXAMDATE'] - group['EXAMDATE'].iloc[0]).dt.days.values
        
        # Create sequence with dynamic padding
        seq_length = len(group)
        padded_features = np.zeros((max_visits, len(features)))
        padded_time = np.zeros(max_visits)
        
        # Fill available data
        valid_length = min(seq_length, max_visits)
        padded_features[:valid_length] = group[features].values[:valid_length]
        padded_time[:valid_length] = time_diff[:valid_length]
        
        # Normalize time
        padded_time = padded_time / time_window
        
        # Combine features and time
        combined = np.concatenate([padded_features, padded_time.reshape(-1,1)], axis=1)
        sequences.append(combined)
        labels.append(group['DX.bl'].values[-1])
    
    return np.array(sequences, dtype='float32'), np.array(labels)

X, y = create_sequences(cleaned_df)
print(f"Generated {len(X)} sequences with shape {X.shape}")

# Step 5: Robust Data Preprocessing
# Normalize features (excluding categoricals)
cont_features = ['AGE', 'PTEDUCAT', 'MMSE']
cat_features = ['PTGENDER', 'APOE4', 'imputed_genotype', 'Allele1', 'Allele2']

# Separate features for normalization
X_cont = X[:, :, [0,2,7]]  # AGE, PTEDUCAT, MMSE
X_cat = X[:, :, [1,3,4,5,6]]  # Categorical features

# Normalize continuous features
scaler = StandardScaler()
X_cont_reshaped = X_cont.reshape(-1, X_cont.shape[-1])
X_cont_normalized = scaler.fit_transform(X_cont_reshaped).reshape(X_cont.shape)

# Recombine features
X_processed = np.concatenate([X_cont_normalized, X_cat], axis=2)

# Handle class imbalance
try:
    smote = SMOTE(random_state=42)
    X_flat = X_processed.reshape(X_processed.shape[0], -1)
    X_balanced, y_balanced = smote.fit_resample(X_flat, y)
    X_balanced = X_balanced.reshape(-1, X_processed.shape[1], X_processed.shape[2])
except ValueError as e:
    print(f"SMOTE error: {e}")
    X_balanced, y_balanced = X_processed, y

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced, test_size=0.2, stratify=y_balanced, random_state=42
)

# Step 6: Enhanced Genetic-Aware LSTM with Attention
def build_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # Separate features
    cont_features = inputs[:, :, :3]  # Normalized continuous features
    cat_features = inputs[:, :, 3:]   # Categorical features
    
    # Embedding layers with dynamic input_dim
    gender_emb = Embedding(input_dim=2, output_dim=2)(cat_features[:, :, 0])
    apoe4_emb = Embedding(input_dim=3, output_dim=2)(cat_features[:, :, 1])
    allele1_emb = Embedding(input_dim=5, output_dim=2)(cat_features[:, :, 3])
    allele2_emb = Embedding(input_dim=5, output_dim=2)(cat_features[:, :, 4])
    
    # Concatenate all features
    merged = Concatenate(axis=-1)([
        cont_features,
        gender_emb,
        apoe4_emb,
        cat_features[:, :, 2:3],  # imputed_genotype
        allele1_emb,
        allele2_emb
    ])
    
    # LSTM with attention
    lstm_out = LSTM(64, return_sequences=True)(merged)
    lstm_out = LayerNormalization()(lstm_out)
    
    # Temporal Attention
    query = LSTM(32, return_sequences=True)(lstm_out)
    value = LSTM(32, return_sequences=True)(lstm_out)
    context = Attention()([query, value])
    
    # Global pooling to reduce sequence dimension
    pooled = GlobalAveragePooling1D()(context)
    
    # Classification
    x = Dense(32, activation='swish')(pooled)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

model = build_model((X_train.shape[1], X_train.shape[2]), len(np.unique(y_balanced)))

# Step 7: Model Training with Enhanced Validation
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    class_weight={i: len(y_balanced)/(len(np.unique(y_balanced)) * np.sum(y_balanced == i)) 
                 for i in np.unique(y_balanced)},
    callbacks=[early_stop]
)

# Step 8: Comprehensive Model Evaluation
y_pred = model.predict(X_test).argmax(axis=1)
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# Confusion Matrix
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Step 9: Enhanced Attention Visualization
def plot_attention(patient_idx):
    attention_model = Model(inputs=model.input,
                           outputs=model.layers[-5].output)  # Adjusted layer index
    attention_weights = attention_model.predict(X_test[patient_idx:patient_idx+1])
    
    plt.figure(figsize=(10,4))
    plt.imshow(attention_weights[0].T, cmap='viridis')
    plt.title('Attention Heatmap Across Visits')
    plt.xlabel('Visit Sequence')
    plt.ylabel('Feature Importance')
    plt.colorbar()
    plt.show()

plot_attention(0)
# Out:
# Retained 628/628 samples after initial cleaning
# Generated 628 sequences with shape (628, 3, 9)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 145ms/step - accuracy: 0.2853 - loss: 1.1038 - val_accuracy: 0.5918 - val_loss: 1.0566
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5346 - loss: 1.0419 - val_accuracy: 0.5918 - val_loss: 0.9070
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6224 - loss: 0.8602 - val_accuracy: 0.6122 - val_loss: 0.7215
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6791 - loss: 0.7143 - val_accuracy: 0.6531 - val_loss: 0.6849
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7135 - loss: 0.6423 - val_accuracy: 0.7007 - val_loss: 0.6456
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6987 - loss: 0.6378 - val_accuracy: 0.6599 - val_loss: 0.6944
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7146 - loss: 0.5734 - val_accuracy: 0.6939 - val_loss: 0.6177
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6836 - loss: 0.6189 - val_accuracy: 0.7075 - val_loss: 0.6133
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7201 - loss: 0.5773 - val_accuracy: 0.7007 - val_loss: 0.6043
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7458 - loss: 0.5633 - val_accuracy: 0.6803 - val_loss: 0.6093
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7258 - loss: 0.5607 - val_accuracy: 0.6939 - val_loss: 0.5970
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6988 - loss: 0.5669 - val_accuracy: 0.7007 - val_loss: 0.6154
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7285 - loss: 0.5606 - val_accuracy: 0.6939 - val_loss: 0.6107
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7261 - loss: 0.5870 - val_accuracy: 0.5986 - val_loss: 0.7339
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6795 - loss: 0.6161 - val_accuracy: 0.7143 - val_loss: 0.5950
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7650 - loss: 0.5168 - val_accuracy: 0.6939 - val_loss: 0.6296
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7361 - loss: 0.5616 - val_accuracy: 0.7007 - val_loss: 0.6016
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7097 - loss: 0.5589 - val_accuracy: 0.6599 - val_loss: 0.6741
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7657 - loss: 0.5131 - val_accuracy: 0.6939 - val_loss: 0.6054
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7118 - loss: 0.5709 - val_accuracy: 0.7007 - val_loss: 0.6305
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7056 - loss: 0.6062 - val_accuracy: 0.7007 - val_loss: 0.6230
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7624 - loss: 0.5366 - val_accuracy: 0.6735 - val_loss: 0.6049
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7486 - loss: 0.5177 - val_accuracy: 0.6871 - val_loss: 0.6476
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7351 - loss: 0.5424 - val_accuracy: 0.7007 - val_loss: 0.5973
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.7292 - loss: 0.5370 - val_accuracy: 0.7007 - val_loss: 0.6163
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7555 - loss: 0.5160 - val_accuracy: 0.6259 - val_loss: 0.7538
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7114 - loss: 0.5773 - val_accuracy: 0.7143 - val_loss: 0.5941
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.7774 - loss: 0.4823 - val_accuracy: 0.6803 - val_loss: 0.5981
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7194 - loss: 0.5636 - val_accuracy: 0.7075 - val_loss: 0.6025
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7609 - loss: 0.5017 - val_accuracy: 0.6735 - val_loss: 0.6118
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7663 - loss: 0.5147 - val_accuracy: 0.6735 - val_loss: 0.5987
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7479 - loss: 0.5315 - val_accuracy: 0.7007 - val_loss: 0.5945
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7613 - loss: 0.5061 - val_accuracy: 0.7007 - val_loss: 0.6263
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7682 - loss: 0.5029 - val_accuracy: 0.6803 - val_loss: 0.6316
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7755 - loss: 0.4910 - val_accuracy: 0.6871 - val_loss: 0.6059
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7784 - loss: 0.4971 - val_accuracy: 0.7007 - val_loss: 0.5950
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7063 - loss: 0.5479 - val_accuracy: 0.6871 - val_loss: 0.6015
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7772 - loss: 0.5226 - val_accuracy: 0.6735 - val_loss: 0.6333
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7626 - loss: 0.5013 - val_accuracy: 0.7075 - val_loss: 0.5984
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7614 - loss: 0.5027 - val_accuracy: 0.6871 - val_loss: 0.6077
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7784 - loss: 0.5172 - val_accuracy: 0.7007 - val_loss: 0.5928
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7891 - loss: 0.4867 - val_accuracy: 0.6939 - val_loss: 0.5726
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7440 - loss: 0.4984 - val_accuracy: 0.6735 - val_loss: 0.5890
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7730 - loss: 0.4824 - val_accuracy: 0.7007 - val_loss: 0.5864
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7756 - loss: 0.4796 - val_accuracy: 0.6871 - val_loss: 0.6217
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7738 - loss: 0.4953 - val_accuracy: 0.7075 - val_loss: 0.5777
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7549 - loss: 0.5366 - val_accuracy: 0.7075 - val_loss: 0.6377
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8138 - loss: 0.4663 - val_accuracy: 0.6735 - val_loss: 0.5907
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7899 - loss: 0.4764 - val_accuracy: 0.6803 - val_loss: 0.6231
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7822 - loss: 0.4631 - val_accuracy: 0.6871 - val_loss: 0.6001
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7868 - loss: 0.4956 - val_accuracy: 0.6939 - val_loss: 0.6108
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7764 - loss: 0.4650 - val_accuracy: 0.6531 - val_loss: 0.6260
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8015 - loss: 0.4551 - val_accuracy: 0.7075 - val_loss: 0.6349
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.7916 - loss: 0.4654 - val_accuracy: 0.6939 - val_loss: 0.6253
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7982 - loss: 0.4802 - val_accuracy: 0.6871 - val_loss: 0.6020
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7982 - loss: 0.4509 - val_accuracy: 0.6735 - val_loss: 0.6072
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8087 - loss: 0.4396 - val_accuracy: 0.6599 - val_loss: 0.6254
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step
#               precision    recall  f1-score   support
#
#           AD       0.77      0.89      0.82        61
#           CN       0.75      0.75      0.75        61
#         LMCI       0.58      0.49      0.53        61
#
#     accuracy                           0.71       183
#    macro avg       0.70      0.71      0.70       183
# weighted avg       0.70      0.71      0.70       183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
